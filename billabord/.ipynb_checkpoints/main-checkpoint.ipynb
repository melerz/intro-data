# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pdb

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import chi2
from sklearn.metrics import log_loss
from sklearn.metrics import confusion_matrix
from sklearn import metrics

from sklearn.preprocessing import StandardScaler
from mpl_toolkits.mplot3d import Axes3D
import requests as req

# import bokeh
# from bokeh.io import output_notebook, show
# from bokeh.resources import INLINE
# import bokeh.plotting as bp
# from bokeh.plotting import figure
#output_notebook(resources=INLINE)



mpl.style.use('seaborn')
mpl.rcParams['figure.figsize'] = [20,15]
mpl.rcParams['axes.titlesize'] = 20
mpl.rcParams['axes.labelsize'] = 16
mpl.rcParams['xtick.labelsize'] =15
mpl.rcParams['ytick.labelsize'] = 15
mpl.rcParams['legend.fontsize'] = 15
pd.options.mode.chained_assignment = None


PLT_WIDTH_INCH = 20
PLT_HEIGHT_INCH = 15
plt.rcParams['figure.figsize'] = [PLT_WIDTH_INCH, PLT_HEIGHT_INCH]

# %load_ext autoreload
# %matplotlib inline



#task specific modules
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # LOAD DATA

# %%
#features correlation
all_features_from_spotify = pd.read_pickle('all_features_from_spotify_with_genres.dat')
popular_songs = pd.read_pickle('final_popular_songs.dat')
random_songs = pd.read_pickle('final_random_songs.dat')
all_songs = pd.read_pickle('final_all_songs.dat')
all_genres = list(pd.read_pickle('all_genres.dat')[0].values)
GENRES = list(pd.read_pickle('spotify_genres.dat')[0].values)

# %% [markdown]
# # FUNCTIONS

# %%
# %load spotify_client/spotify_client.py
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials


"""
we will get all the features from spotify, by song name and artist name.
this function will create a json file with all the data
"""
def get_song_features_and_info_json(song_name, artist_name):

    # getting credentials to request special API
    credenials = SpotifyClientCredentials(client_id="5659eaf41b194134866170761e2fb293",client_secret="17e2a9fa37c2466baa2ba05752896cdc")

    # getting the client
    spotify_client = spotipy.Spotify(client_credentials_manager=credenials)

    # getting the song id in order to retrieve features, limiting to 1 since it sorts the results by popularity
    song_results = spotify_client.search(q='artist:' + artist_name + ' track:' + song_name, type='track',limit=1)
    #print(song_results)
    tracks = song_results['tracks']['items']
    if len(tracks)==0:
        print("***no results for the requested track:{}***".format(song_name+":"+artist_name))
        return
    result_dict = tracks[0]

    # creating dict for track
    song_dict = creating_song_dictionary(artist_name, result_dict, spotify_client)

    return song_dict
def creating_song_dictionary(artist_name, result_dict, spotify_client):
    song_dict = {}
    song_dict['artist'] = artist_name
    song_id = [result_dict['uri']]
    song_dict['uri'] = song_id
    song_dict['year'] = result_dict['album']['release_date'][:4]
    song_dict['artist_id'] = result_dict['artists'][0]['id']
    song_dict['track_id'] = result_dict['id']
    song_dict['name'] = spotify_client.track(song_dict['track_id'])['name']
    song_dict['popularity'] = result_dict['popularity']
    song_dict['preview_link'] = result_dict['preview_url']
    features = spotify_client.audio_features(song_id)
    song_dict['main_features'] = features[0]

    # todo - need this? a big analysis, maybe will be helpful
    # analysis = spotify_client._get(features[0]['analysis_url'])
    #
    # song_dict['analysis'] = analysis

    return song_dict



SPOTIFY_COLUMNS = ['artist','artist_id','name','genre','decade','duration_ms','acousticness',
                  'danceability','energy','id',
                  'instrumentalness','liveness','loudness','speechiness','tempo','valence','popular']


selected_columns=['duration_ms','acousticness',
                  'danceability','energy',
                  'instrumentalness','liveness','loudness','speechiness','tempo','valence']

def plot_statistics(df,column='num_words'):
    df.groupby('decade')[column].describe().T.plot(kind='box',title='{}'.format(column),figsize=(10,5))
    
    
def get_artist_and_title(df):
    #return ["{}:{}".format(tup[0],tup[1]) for tup in list(zip(zz.loc['artist'].values,zz.loc['title'].values))]
    return list(zip(df.loc[:,'name'].values,df.loc[:,'artist'].values))



def scale_features(data):
    scaler = StandardScaler(with_mean=True)
    return pd.DataFrame(scaler.fit_transform(data))



# getting credentials to request special API
credenials = SpotifyClientCredentials(client_id="5659eaf41b194134866170761e2fb293",client_secret="17e2a9fa37c2466baa2ba05752896cdc")

# getting the client
spotify_client = spotipy.Spotify(client_credentials_manager=credenials)

import re

def get_artist_genre(spotify_client,artist_id):
    artist_data = spotify_client.artist(artist_id)
    spotify_genres = artist_data["genres"]
    return spotify_genres

def get_number_of_apearence(genre,spotify_genres):
    count=0
    for spot_genre in spotify_genres:
        res = re.search(genre, spot_genre)
        if res:
            count+=1
    return count

def get_genres_scores_of_artist(spotify_client,artist_id):
    artist_genres=get_artist_genre(spotify_client,artist_id)
    return [get_number_of_apearence(genre,artist_genres) for genre in GENRES]

def get_genre_of_artist(spotify_client,artist_id):
    scores=get_genres_scores_of_artist(spotify_client,artist_id)
    if np.sum(scores)==0:
        return 'na'
    return GENRES[np.argmax(scores)]



def remove_dup_songs_from_random(all_songs_data_frame,subset):
    res=all_songs_data_frame.drop_duplicates(subset = subset,keep = 'first',inplace = False)
    return res


def get_year(artist,title):
    try:
        res=req.get('https://api.discogs.com/database/search?artist={0}&release_title={1}&per_page=10&page=1&token=AVfnfICgSgXIDXAWivYivedRIhMcDRvYCxrIshPk'.format(artist,title))
        return np.min([np.int(r['year']) for r in res.json()['results'] if 'year' in r.keys()]) 
    except Exception as e:
        #print(e)
        return None
    
def get_all_fixed_years(data):
    years=[]
    details=get_artist_and_title(data)
    for name,artist in details:
        year=get_year(artist,name)
        years.append(year)
        print(year)
    return years

# %% [markdown]
# Preprocessig

# %%
#df=pd.read_pickle('billboard.dat')

def cleaning_and_typing(df):    
    df.columns=np.arange(df.shape[1])
    df['num_words']=df['num_words'].astype(int)
    df['num_lines']=df['num_lines'].astype(int)
    df['num_dupes']=df['num_dupes'].astype(int)

    df['title'].replace(regex=True,to_replace=r"\'",value=r'',inplace=True)
    df['artist'].replace(regex=True,to_replace=r"\'",value=r'',inplace=True)
    return df
    
def create_decade_mappings():
    all_years=np.arange(1950,2016)
    decades=np.arange(1950,2016,10)
    decades_mappings={}
    cur_dec=decades[0]
    cur_dec_idx=0
    for year in all_years:
        if year%cur_dec>=10:
            cur_dec_idx+=1
            cur_dec=decades[cur_dec_idx]
        decades_mappings.update({year:cur_dec})
    return decades_mappings



def spotify_preprocessing(df,is_popular=False):
    #add decade
    df['year']=df['year'].astype(int)
    zz=df['year'].map(create_decade_mappings())
    zz=zz.fillna(1950)
    df.loc[:,'decade']=zz.astype(int)
    
    #clean artists
    df['name'].replace(regex=True,to_replace=r"\'",value=r'',inplace=True)
    df['artist'].replace(regex=True,to_replace=r"\'",value=r'',inplace=True)
    
    #add genre information for each song
    df.loc[:,'genre']=df['artist_id'].apply(lambda artist_id:get_genre_of_artist(spotify_client,artist_id))
    
    #add popular column
    df.loc[:,'popular']=np.int(is_popular)
    
    #extract relevant columns only
    return df[SPOTIFY_COLUMNS]

# %%
df.groupby('decade').apply(lambda decade: len(decade)).plot(kind='bar',figsize=(10,5),title='Decades Songs Distribution')
plt.ylabel('# Hit Songs')


plt.figure()
top_art=20
df['artist'].value_counts().head(top_art).plot(kind='bar',figsize=(10,5),title='Top {} Aritst'.format(top_art))
plt.ylabel('# Hit Songs')

# %%
plot_statistics(df,'num_dupes')
plot_statistics(df,'num_words')
plot_statistics(df,'difficult_words')

# %%
title_art=get_artist_and_title(df.T)
songs_data=[]
missings=[]
count=0
start=696
for title,art in title_art[start:]:
    count+=1
    print(count)
    try:
        cur_song_features=get_song_features_and_info_json(title,art)
        if cur_song_features:
            songs_data.append(cur_song_features)
        else:
            missings.append(cur_song_features)
    except Exception as e:
        print(e)
        missings.append(cur_song_features)
    if(count%100)==0:
        print('Saving data..')
        pd.DataFrame(songs_data).to_pickle('songs_features_2.dat')

# %%
#kmeans
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=7)
kmeans_data=all_features_from_spotify[selected_columns]
kmeans.fit(kmeans_data)
labels = kmeans.predict(kmeans_data)

# %%
clrs={0:'r',1:'b',2:'g',3:'y',4:'magenta',5:'cyan',6:'brown'}
kmeans_clrs = [clrs[idx] for idx in labels]

# %%
clrs={1950:'r',1960:'b',1970:'g',1980:'y',1990:'magenta',2000:'cyan',2010:'brown'}
decade_clrs = [clrs[row[1]['decade']] for row in all_features_from_spotify.iterrows()]

# %%
rand_colors=np.random.rand(3,len(GENRES))
genres_clrs = [rand_colors[:,GENRES.index(row[1]['genre'])] for row in all_features_from_spotify.iterrows()]

# %%
def scale_features(data):
    scaler = StandardScaler(with_mean=True)
    return pd.DataFrame(scaler.fit_transform(data))

# %%
selected_columns=['duration_ms','acousticness',
                  'danceability','energy',
                  'instrumentalness','liveness','loudness','speechiness','tempo','valence']

# %%
#features correlation
all_features_from_spotify[selected_columns].corr().style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row0_col0 {
#             background-color:  #023858;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row0_col1 {
#             background-color:  #dddbec;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row0_col2 {
#             background-color:  #b9c6e0;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row0_col3 {
#             background-color:  #89b1d4;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row0_col4 {
#             background-color:  #eee9f3;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row0_col5 {
#             background-color:  #f4eef6;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row0_col6 {
#             background-color:  #abbfdc;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row0_col7 {
#             background-color:  #e0deed;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row0_col8 {
#             background-color:  #f1ebf4;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row0_col9 {
#             background-color:  #fdf5fa;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row1_col0 {
#             background-color:  #fff7fb;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row1_col1 {
#             background-color:  #023858;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row1_col2 {
#             background-color:  #fff7fb;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row1_col3 {
#             background-color:  #fff7fb;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row1_col4 {
#             background-color:  #fbf4f9;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row1_col5 {
#             background-color:  #e8e4f0;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row1_col6 {
#             background-color:  #fff7fb;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row1_col7 {
#             background-color:  #fff7fb;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row1_col8 {
#             background-color:  #faf2f8;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row1_col9 {
#             background-color:  #fff7fb;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row2_col0 {
#             background-color:  #bfc9e1;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row2_col1 {
#             background-color:  #e0deed;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row2_col2 {
#             background-color:  #023858;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row2_col3 {
#             background-color:  #65a3cb;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row2_col4 {
#             background-color:  #f0eaf4;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row2_col5 {
#             background-color:  #fff7fb;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row2_col6 {
#             background-color:  #94b6d7;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row2_col7 {
#             background-color:  #b9c6e0;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row2_col8 {
#             background-color:  #fff7fb;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row2_col9 {
#             background-color:  #529bc7;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row3_col0 {
#             background-color:  #bcc7e1;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row3_col1 {
#             background-color:  #fff7fb;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row3_col2 {
#             background-color:  #91b5d6;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row3_col3 {
#             background-color:  #023858;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row3_col4 {
#             background-color:  #f4edf6;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row3_col5 {
#             background-color:  #d9d8ea;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row3_col6 {
#             background-color:  #04649d;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row3_col7 {
#             background-color:  #c2cbe2;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row3_col8 {
#             background-color:  #cacee5;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row3_col9 {
#             background-color:  #78abd0;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row4_col0 {
#             background-color:  #c8cde4;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row4_col1 {
#             background-color:  #abbfdc;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row4_col2 {
#             background-color:  #c5cce3;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row4_col3 {
#             background-color:  #9fbad9;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row4_col4 {
#             background-color:  #023858;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row4_col5 {
#             background-color:  #efe9f3;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row4_col6 {
#             background-color:  #c6cce3;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row4_col7 {
#             background-color:  #eee8f3;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row4_col8 {
#             background-color:  #ede7f2;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row4_col9 {
#             background-color:  #dddbec;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row5_col0 {
#             background-color:  #dedcec;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row5_col1 {
#             background-color:  #9ebad9;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row5_col2 {
#             background-color:  #e7e3f0;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row5_col3 {
#             background-color:  #89b1d4;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row5_col4 {
#             background-color:  #f8f1f8;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row5_col5 {
#             background-color:  #023858;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row5_col6 {
#             background-color:  #adc1dd;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row5_col7 {
#             background-color:  #d3d4e7;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row5_col8 {
#             background-color:  #e7e3f0;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row5_col9 {
#             background-color:  #e0deed;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row6_col0 {
#             background-color:  #c6cce3;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row6_col1 {
#             background-color:  #f1ebf5;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row6_col2 {
#             background-color:  #abbfdc;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row6_col3 {
#             background-color:  #046198;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row6_col4 {
#             background-color:  #fff7fb;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row6_col5 {
#             background-color:  #e4e1ef;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row6_col6 {
#             background-color:  #023858;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row6_col7 {
#             background-color:  #c5cce3;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row6_col8 {
#             background-color:  #dcdaeb;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row6_col9 {
#             background-color:  #d2d3e7;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row7_col0 {
#             background-color:  #cdd0e5;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row7_col1 {
#             background-color:  #c8cde4;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row7_col2 {
#             background-color:  #9ebad9;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row7_col3 {
#             background-color:  #79abd0;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row7_col4 {
#             background-color:  #fdf5fa;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row7_col5 {
#             background-color:  #d9d8ea;
#         }    #T_e5ee0f14_3418_11e9_84be_b4ae2b1ef5e4row7_col6 {
#             bac

# %% [markdown]
# we can see we have expected correlation between energy and loudness, but nothing more.

# %%
#PCA
from sklearn.decomposition import PCA

pca_data=all_features_from_spotify[selected_columns]

#make std=1 and mean=0
pca_data = scale_features(pca_data)

N=3
pca = PCA(n_components=N,svd_solver='full')
pca.fit(pca_data)

X_pca = pca.transform(pca_data)

# %%
print(pca.components_)
# Out:
# [[-0.1289073   0.4760612  -0.32866172 -0.53981982 -0.01853113 -0.03176706
#   -0.45214805 -0.21607416 -0.09313693 -0.31011569]
#  [ 0.23984063 -0.1302443  -0.57838931  0.17029427 -0.12858456  0.26763168
#    0.3108207  -0.0331573   0.31355195 -0.52706177]]

# %%
fig=plt.figure(figsize=(12, 10))
#plt.scatter(X_pca[:,0],X_pca[:,1],X_pca[:,2],c=decade_clrs)
#plt.title('PCA - Color by decades')
ax = Axes3D(fig)
ax.scatter(X_pca[:,0],X_pca[:,1],X_pca[:,2],c=genres_clrs,s=20)

# %%
plt.figure(figsize=(12, 10))
plt.scatter(X_pca[:,0],X_pca[:,1],c=kmeans_clrs)
plt.title('PCA - Color by kmeans')

# %%
plt.plot(abs(pca.components_[1]))

# %% [markdown]
# ## Get all genres from everynoise

# %%
# import requests
# from bs4 import BeautifulSoup
# url = 'http://everynoise.com/everynoise1d.cgi?scope=all'
# r = requests.get(url)
# html_content = r.text
# soup = BeautifulSoup(html_content, 'lxml')

# links=soup.find_all("a", {"title": "Re-sort the list starting from here."})
# all_genres=[link.text for link in links]

# %%
import itertools
splitted_genres=[gen.split() for gen in all_genres]

splitted_genres = list(itertools.chain(*splitted_genres))

pd.DataFrame(splitted_genres)[0].value_counts().head(50).plot(kind='bar',figsize=(12,8))

# %%
TOP_GENRES=20
GENRES=list(pd.DataFrame(splitted_genres)[0].value_counts().head(TOP_GENRES).keys())
#fix hip and hop
GENRES=[g for g in GENRES if g not in ['hip','hop']]
GENRES+=['country','christmas','disco','funk','soul','na','hip hop']
GENRES
# Out:
# ['indie',
#  'pop',
#  'rock',
#  'metal',
#  'deep',
#  'classical',
#  'jazz',
#  'folk',
#  'punk',
#  'house',
#  'alternative',
#  'classic',
#  'rap',
#  'black',
#  'swedish',
#  'blues',
#  'contemporary',
#  'german',
#  'country',
#  'christmas',
#  'disco',
#  'funk',
#  'soul',
#  'na',
#  'hip hop']

# %%
# #add genre information for each song
# all_features_from_spotify['genre']=all_features_from_spotify['artist_id'].apply(lambda artist_id:get_genre_of_artist(spotify_client,artist_id))

# %%
#genres distribution
all_features_from_spotify['genre'].value_counts().plot(kind='bar',title='Genre Popularity',figsize=(12,8))

# %% [markdown]
# ## Merge data with hanit

# %%
random_songs_old = pd.read_pickle('final_random_songs.dat')
popular_songs = pd.read_pickle('final_popular_songs.dat')

# %%
#merge

frames= [popular_songs, random_songs]
all_songs_data = pd.concat(frames)


def remove_dup_songs_from_random(all_songs_data_frame,subset):
    res=all_songs_data_frame.drop_duplicates(subset = subset,keep = 'first',inplace = False)
    return res

all_songs_wo_dups = remove_dup_songs_from_random(all_songs_data,['name','artist'])
all_songs_wo_dups
# Out:
#     acousticness                artist               artist_id  danceability  \
# 0       0.903000         Nat King Cole  7v4imS0moSyGdXyLgVTIV7         0.214
# 1       0.930000       Andrews Sisters  2NCGI6dLTxLdI9XHdv7QfM         0.387
# 2       0.971000            Patti Page  4nZN9kln8toEzOifhWG2uF         0.475
# 3       0.795000  Tennessee Ernie Ford  7by3Je8PERsotbZ7xLWaDH         0.703
# 4       0.886000            Patti Page  4nZN9kln8toEzOifhWG2uF         0.608
# 5       0.910000            Perry Como  5v8jlSmAQfrkTjAlpUfWtu         0.645
# 6       0.896000           Bing Crosby  6ZjFtWeHP9XN7FeKSUe80S         0.778
# 7       0.824000         Frankie Laine  3cgO5CdhEHKMxldjZlP5ix         0.637
# 8       0.805000         Nat King Cole  7v4imS0moSyGdXyLgVTIV7         0.201
# 9       0.940000          Tony Bennett  2lolQgalUvZDfp5vvVtTYV         0.248
# 10      0.826000      Rosemary Clooney  0NkyXWGxE3WTFixDSJ39PK         0.527
# 11      0.890000           Mario Lanza  6umNMJq7B8UdOVmwPV6PRL         0.216
# 12      0.968000          Tony Bennett  2lolQgalUvZDfp5vvVtTYV         0.370
# 13      0.903000            Perry Como  5v8jlSmAQfrkTjAlpUfWtu         0.288
# 15      0.835000         Frankie Laine  3cgO5CdhEHKMxldjZlP5ix         0.504
# 16      0.750000            Patti Page  4nZN9kln8toEzOifhWG2uF         0.561
# 17      0.801000         Frankie Laine  3cgO5CdhEHKMxldjZlP5ix         0.336
# 18      0.924000            Perry Como  5v8jlSmAQfrkTjAlpUfWtu         0.649
# 19      0.865000            Les Baxter  35pV6EUbherudlvAftoueR         0.238
# 20      0.944000      Rosemary Clooney  0NkyXWGxE3WTFixDSJ39PK         0.277
# 21      0.814000            Patti Page  4nZN9kln8toEzOifhWG2uF         0.408
# 22      0.672000            Al Martino  7egNqIGRldMzifHoh8pib6         0.210
# 23      0.802000      Rosemary Clooney  0NkyXWGxE3WTFixDSJ39PK         0.642
# 24      0.901000             Doris Day  3ESG6pj6a0LvUKklENalT6         0.727
# 25      0.935000         Frankie Laine  3cgO5CdhEHKMxldjZlP5ix         0.466
# 26      0.890000            Perry Como  5v8jlSmAQfrkTjAlpUfWtu         0.303
# 27      0.809000            Perry Como  5v8jlSmAQfrkTjAlpUfWtu         0.808
# 28      0.977000         Frankie Laine  3cgO5CdhEHKMxldjZlP5ix         0.402
# 29      0.721000     Frank Chacksfield  01zQA436fdUqmEWvljtzxr         0.101
# 30      0.927000         Nat King Cole  7v4imS0moSyGdXyLgVTIV7         0.370
# ..           ...                   ...                     ...           ...
# 0       0.170000                    YG  0A0FS04o6zMoto8OKPsDwY         0.796
# 0       0.153000            Tyler Farr  3vHV92ecrylnUHDM4d2MtC         0.487
# 0       0.135000         NEEDTOBREATHE  610EjgFatGvVPtib97jQ8G         0.526
# 0       0.887000                   Cam  5WRElKaZsn1tGnrgmJVAeO         0.728
# 0       0.028900         Calvin Harris  7CajNmpbOovFoOoasH2HaY         0.413
# 0       0.562000            Ed Sheeran  6eUKZXaKkcviH0Ku9w2n3V         0.592
# 0       0.000467              The 1975  3mIj9lX2MWuHmhNCA7LSCW         0.617
# 0       0.420000         Michael Bublé  1GxkXlMwML1oSg5eLPiAz3         0.503
# 0       0.313000      Kero Kero Bonito  6OqhFYFJDnBBHas02HopPT         0.788
# 0       0.881000                  EDEN  1t20wYnTiAT0Bs7H1hv9Wt         0.387
# 0       0.474000                  Tink  4v6XOdonnfpdTKTRJArG7v         0.529
# 0       0.032500        Jerrod Niemann  0RKP52f5PNDCRZ9Luq2Sr7         0.639
# 0       0.039500             Lil Wayne  55Aa2cqylxrFIXC767Z865         0.612
# 0       0.037200              Big Sean  0c173mlxpT3dSFRgMO8XPh         0.822
# 0       0.057900           Just A Gent  1kwGj7uDO5WXVXtQLvGJr0         0.574
# 0       0.603000        Jonathan Groff  7KkqUt65v6LMtR369OQ6FB         0.515
# 0       0.389000               J. Cole  6l3HvQ5sa6mXTsMTB19rO5         0.518
# 0       0.006940                 BØRNS  1KP6TWI40m7p3QBTU6u2xo         0.568
# 0       0.101000  Florida Georgia Line  3b8QkneNDz4JHKKKlLgYZg         0.556
# 0       0.755000             Oh Wonder  5cIc3SBFuBLVxJz58W2tU9         0.658
# 0       0.274000            Kanye West  5K4W6rqBFWDnAN6FQUkS6x         0.590
# 0       0.241000               Beyoncé  6vWDO969PvNqNYHIOW5v0m         0.639
# 0       0.005070      Brantley Gilbert  5q8HGNo0BjLWaTAhRtbwxa         0.493
# 0       0.025400        In This Moment  6tbLPxj1uQ6vsRQZI2YFCT         0.604
# 0       0.819000                 gnash  3iri9nBFs9e4wN7PLIetAw         0.654
# 0       0.155000   Diddy - Dirty Money  2QYEvpsWUOjqaYuxDPTCmV         0.353
# 0       0.007090                 Kesha  6LqNN22kT3074XbTVUrhzX         0.734
# 0       0.949000               Wun Two  69cjjIQEN8M6heOBT2SqZE         0.762
# 0       0.337000              Jessie J  2gsggkzM5R49q6jpPvazou         0.379
# 0       0.068200          Broken Bells  6dgwEwnK0YtDfS9XhRwBTG         0.610
#
#     decade  duration_ms  energy      genre                      id  \
# 0     1990       207573  0.1940       jazz  3k5ycyXX5qsCjLd7R2vphp
# 1     2000       198000  0.0958       jazz  6vSKLIxqiYllqDd2VcGVHv
# 2     1960       185000  0.1390        pop  0788TdvEjGtjFVb6CTFdJH
# 3     2010       156987  0.1970         na  1v52YkW75eN4RJ2EyDdQVI
# 4     1990       194333  0.1970        pop  2BNPXyUhq5WFpAO1Ff5yEg
# 5     1980       174040  0.4300        pop  12WJhNxX6EYC2rAlfVOW4d
# 6     1990       160750  0.2910  christmas  28IBsttOK2aG9Cb4QtqhMr
# 7     2010       174813  0.2750        pop  4Gx5Hy6fnfeXcSEnVls6f3
# 8     1990       204627  0.2130       jazz  0zII0Soax7wbm3Avw7iVAd
# 9     2000       242040  0.2200       jazz  1hVEHu6SemMvlYAP5MWkDj
# 10    1950       116933  0.6330       jazz  3GVyT9fBXuEkGs1STo2WHZ
# 11    1950       209293  0.4460        pop  2hOyxXcKUxaZpWKBIfBp8Z
# 12    1950       159520  0.1410       jazz  1nz7qrpaifFdBUp22qde4O
# 13    1990       184040  0.1690        pop  0VLsWxGXctGx9QtaHCpVEk
# 15    1950       190933  0.2650        pop  6SYQwsOxHW5uUYjUpOKtIC
# 16    1970       178867  0.3000        pop  5yzlxi4VFO8UkxepsL0guW
# 17    1950       152307  0.3150        pop  5hQ3Z5zYqHKZBO0pPb16eI
# 18    2000       175213  0.1180        pop  0jVYsBfsxGA7zPurjqnlH8
# 19    1990       170800  0.2070    classic  4WToccEJeXgFNyfNPuSYCS
# 20    1950       166373  0.1890       jazz  5vIe5BmOlPXarqRxJh9FNE
# 21    1990       175333  0.3090        pop  1pfNFUzZIhwPx1m9eqOlfX
# 22    2000       182560  0.2710        pop  5bETzPVHt11c82M57szEJV
# 23    1950       136867  0.6640       jazz  72HUHsM38XhUE7YjA7oxLz
# 24    1950       159507  0.2850        pop  1lZSR5NKeNGuCPSTNL7BhW
# 25    1950       158360  0.2520        pop  1yGBGPgpGi5ua0HbHcvesQ
# 26    1990       196373  0.1870        pop  4iyzrJ3qIGBvG8yl5dWHQ8
# 27    1970       160773  0.4210        pop  2cwTVrrgHxl4gcHY4IHr18
# 28    1950       130893  0.1590        pop  049uxirFkHOefJ0yqPW8Kk
# 29    1960       217267  0.4820  christmas  2jCGELICh9bYpSiJ9bl2vL
# 30    1950       164400  0.2750       jazz  2Gd007dAbihobxsTG9m7cZ
# ..     ...          ...     ...        ...                     ...
# 0     2010       243747  0.5050        rap  3AqcBOSlJF7xMgvLpQoa3c
# 0     2010       216040  0.6670    country  4lcXNTm9JrQpJYXqsENmFI
# 0     2010       208205  0.8030      indie  62M9yafZsSRzlsphzeJPGo
# 0     2010       231333  0.2530    country  2zhk0kypGeOPsaaZcjyc14
# 0     2010       212960  0.8560      house  07nH4ifBxUB4lZcsf44Brn
# 0     2010       185093  0.6370        pop  5ubHAQtKuFfiG4FXfLP804
# 0     2010       254510  0.7040        pop  06cCziAHtDg6pcsidZHu03
# 0     2010       171827  0.4650        pop  1FRqLI971CD1QedTiJeL3c
# 0     2010       197528  0.4900        pop  3AaiEsiqHO2ylnnOdWninE
# 0     2010       279828  0.3760        pop  6K6OCvFQ4i7KKfGJsOAqY1
# 0     2010       238355  0.3600        rap  2mx4wF6IW1mfZmWtENDBUU
# 0     2010       224813  0.8460    country  3M31S6f0z8S3nkFh3eS06W
# 0     2010       223173  0.5930        rap  3Eq7yD58dIXqOgw1j7NFhY
# 0     2010       284387  0.7340        rap  7FYH5AW3bVfZHJIQpq3UOA
# 0     2010       254897  0.5760        rap  3mof6Z6vz6gonsuIEQXank
# 0     2010        99343  0.3020         na  3D4J0o9w44QKFrBrYrSVJY
# 0     2010       264213  0.8090        pop  4txn9qnwK3ILQqv5oq2mO3
# 0     2010       174693  0.5780        pop  2pA4ip3VIEVcIa3qE02oAX
# 0     2010       190640  0.8730    country  6IFPfV8PNSYOmufzQ95hmm
# 0     2010       196466  0.4470        pop  2kJqNHHGOzLNahukdvlDWN
# 0     2010       280787  0.5870        rap  7yNK27ZTpHew0c55VvIJgm
# 0     2010       234413  0.6590        pop  0zVMzJ37VQNFUNvdxxat2E
# 0     2010       225747  0.8430    country  01ZepwW5W3Z4fwl4bzaHyY
# 0     2010       245533  0.8830      metal  2tAzcTFry1OhmNERFjUR93
# 0     2010       240000  0.2350        pop  4jnO4ztskhv3YkqgFnewtD
# 0     2010       238693  0.8220        pop  6Iocm6VMu6bVNYwiDoyQFW
# 0     2010       204150  0.8210        pop  0Ji2g9AlYLVHAMG5PJoHPU
# 0     2010       143133  0.5250         na  24Jk4wYlLRXI9TUMdkHoMN
# 0     2010       209560  0.6180        pop  6SkoBaMd0lzoQjID5aV2d9
# 0     2010       232200  0.6370      indie  5cwN1htZyoWqZCc33f3RfE
#
#     instrumentalness  liveness  loudness  \
# 0           0.000001    0.1070   -15.636
# 1           0.000000    0.1700   -12.278
# 2           0.000173    0.1280   -12.619
# 3           0.000000    0.0982   -11.312
# 4           0.000001    0.1140   -14.830
# 5           0.000000    0.5610   -11.916
# 6           0.000514    0.1470   -12.703
# 7           0.000000    0.2390   -12.261
# 8           0.000082    0.1260   -14.531
# 9           0.001970    0.1090   -10.768
# 10          0.000000    0.4220    -8.560
# 11          0.000007    0.1200    -8.277
# 12          0.000002    0.3380   -14.082
# 13          0.000042    0.3170   -12.024
# 15          0.000000    0.6040   -16.424
# 16          0.000000    0.2830   -13.995
# 17          0.000000    0.1750   -14.154
# 18          0.000000    0.2180   -13.160
# 19          0.000001    0.1350   -12.894
# 20          0.000000    0.2320   -12.424
# 21          0.000076    0.0786   -12.663
# 22          0.341000    0.3390    -9.598
# 23          0.000000    0.1380    -8.485
# 24          0.000000    0.1410   -14.098
# 25          0.000002    0.1710   -17.869
# 26          0.000003    0.1010   -11.615
# 27          0.000000    0.0724   -12.533
# 28          0.000018    0.1550   -18.598
# 29          0.030900    0.5120    -9.563
# 30          0.000000    0.1060   -11.235
# ..               ...       ...       ...
# 0           0.000000    0.1060    -9.529
# 0           0.000000    0.1610    -4.216
# 0           0.000000    0.1190    -3.989
# 0           0.000011    0.1330    -8.427
# 0           0.005710    0.3430    -4.078
# 0           0.000000    0.1300    -8.480
# 0           0.000013    0.3260    -6.835
# 0           0.000000    0.1010    -8.077
# 0           0.000000    0.0968    -6.287
# 0           0.000000    0.8510    -6.743
# 0           0.000000    0.0446   -10.840
# 0           0.000000    0.1160    -6.184
# 0           0.000000    0.4840    -6.294
# 0           0.000000    0.3250    -5.480
# 0           0.001470    0.2080    -8.267
# 0           0.000000    0.1990   -10.882
# 0           0.000000    0.2750    -6.362
# 0           0.000353    0.0990    -5.589
# 0           0.000131    0.1760    -5.056
# 0           0.000004    0.0828    -8.315
# 0           0.000000    0.1670    -5.919
# 0           0.000008    0.4840    -7.273
# 0           0.000000    0.1300    -5.924
# 0           0.000000    0.0813    -3.821
# 0           0.000000    0.0891   -11.292
# 0           0.000000    0.3320    -1.866
# 0           0.002810    0.1270    -4.893
# 0           0.870000    0.1140   -11.863
# 0           0.000005    0.1020    -7.065
# 0           0.000006    0.2840    -6.574
#
#                                                  name  popular  speechiness  \
# 0                                           Mona Lisa        1       0.0325
# 1                   I Wanna Be Loved - Single Version        1       0.0391
# 2                                     Tennessee Waltz        1       0.0333
# 3                                  I'll Never Be Free        1       0.0327
# 4                                         All My Love        1       0.0446
# 5                                        Hoop-Dee-Doo        1       0.0444
# 6                       Dear Hearts And Gentle People        1       0.0390
# 7                           The Cry of the Wild Goose        1       0.0386
# 8                                           Too Young        1       0.0298
# 9                                      Because of You        1       0.0299
# 10                                 Come On-A My House        1       0.1140
# 11                            Be My Love - Remastered        1       0.0340
# 12                                    Cold Cold Heart        1       0.0390
# 13                                                 If        1       0.0294
# 15                                            Jezebel        1       0.0344
# 16                                  Mockin' Bird Hill        1       0.0422
# 17                             Rose, Rose, I Love You        1       0.0432
# 18                 You're Just In Love (I Wonder Why)        1       0.0513
# 19                                     Because Of You        1       0.0301
# 20    Half As Much (with Percy Faith & His Orchestra)        1       0.0329
# 21                             I Went to Your Wedding        1       0.0282
# 22                                   Here In My Heart        1       0.0330
# 23                 Botch-A-Me (Ba-Ba-Baciami Piccina)        1       0.0934
# 24                                     A Guy Is a Guy        1       0.0457
# 25                                          High Noon        1       0.0416
# 26  No Other Love (with Henri René & His Orchestra...        1       0.0295
# 27               Don't Let The Stars Get In Your Eyes        1       0.0420
# 28                                          I Believe        1       0.0306
# 29                                           Ebb Tide        1       0.0374
# 30                                            Pretend        1       0.0290
# ..                                                ...      ...          ...
# 0                                 Toot It And Boot It        0       0.1000
# 0                                       Redneck Crazy        0       0.0309
# 0                        Brother (feat. Gavin DeGraw)        0       0.1270
# 0                                       Burning House        0       0.0304
# 0                                               Blame        0       0.0808
# 0                                          Lego House        0       0.0992
# 0                                             Robbers        0       0.0301
# 0                     All I Want for Christmas Is You        0       0.0274
# 0                                            Flamingo        0       0.5110
# 0                                             Wake Up        0       0.0338
# 0                              Treat Me Like Somebody        0       0.1130
# 0                             Drink to That All Night        0       0.0439
# 0                                        Rich As Fuck        0       0.4580
# 0                               I Don't Fuck With You        0       0.0738
# 0                           Limelight (NGHTMRE Remix)        0       0.0446
# 0                                    What Comes Next?        0       0.0802
# 0                                     03' Adolescence        0       0.5660
# 0                                10,000 Emerald Pools        0       0.0404
# 0                                          Confession        0       0.0348
# 0                                               Drive        0       0.0987
# 0                                        Dark Fantasy        0       0.0457
# 0                                      Flawless Remix        0       0.2150
# 0                               Kick It In The Sticks        0       0.0707
# 0                                               Whore        0       0.0470
# 0                                       feelings fade        0       0.1590
# 0                                         Coming Home        0       0.2320
# 0                                       We R Who We R        0       0.0406
# 0                                               Again        0       0.1990
# 0      Flashlight - From "Pitch Perfect 2" Soundtrack        0       0.0586
# 0                                       The High Road        0       0.0238
#
#       tempo  valence
# 0    86.198   0.3390
# 1   167.122   0.2240
# 2    86.156   0.3740
# 3    82.114   0.4690
# 4   123.357   0.6390
# 5   132.643   0.9440
# 6   107.730   0.6950
# 7    80.044   0.4540
# 8    96.324   0.2030
# 9    71.377   0.1910
# 10  183.174   0.9610
# 11   80.422   0.2470
# 12   66.305   0.3030
# 13   71.412   0.2290
# 15  136.721   0.3930
# 16  109.795   0.5630
# 17  202.391   0.9380
# 18   74.990   0.5490
# 19   97.574   0.3030
# 20   86.655   0.2080
# 21   90.702   0.2570
# 22   61.278   0.2280
# 23  148.866   0.9590
# 24  120.195   0.7590
# 25  140.970   0.3380
# 26   90.486   0.2300
# 27  122.752   0.9630
# 28   67.796   0.2820
# 29  166.982   0.0554
# 30   82.137   0.3080
# ..      ...      ...
# 0    95.003   0.2630
# 0   145.854   0.4630
# 0   157.887   0.5640
# 0   140.923   0.4570
# 0   128.017   0.3500
# 0   159.701   0.5650
# 0    99.804   0.3580
# 0   141.796   0.1430
# 0   177.865   0.7900
# 0   116.667   0.3950
# 0   129.387   0.5530
# 0   115.965   0.4750
# 0   130.583   0.8830
# 0    97.998   0.4250
# 0   145.094   0.2870
# 0   114.832   0.2760
# 0   146.216   0.2610
# 0   139.951   0.5550
# 0   104.986   0.4800
# 0   141.742   0.3970
# 0    88.015   0.3670
# 0   136.801   0.4570
# 0   158.028   0.5230
# 0    90.001   0.5440
# 0    88.903   0.0610
# 0   167.905   0.2370
# 0   119.993   0.6480
# 0    82.777   0.6520
# 0   147.530   0.4000
# 0    79.955   0.6090
#
# [6261 rows x 17 columns]

# %%
all_songs.groupby('decade').apply(lambda x:x['popular'].value_counts()).plot(kind='bar')

# %%
get_all_fixed_years(all_songs.head(5))
# Out:
# 1
# 'results'
# 2
# 3
# 'results'
# 4
# 'results'
# 5
# [1972, None, 1963, None, None]

# %%
def evaluate_models(features,labels,models,scoring_method='accuracy',CV=5):
    cv_df = pd.DataFrame(index=range(CV * len(models)))
    entries = []
    for model in models:
        model_name = model.__class__.__name__
        accuracies = cross_val_score(model,features, labels, scoring=scoring_method, cv=CV)
        for fold_idx, accuracy in enumerate(accuracies):
            entries.append((model_name, fold_idx, accuracy))
    cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', scoring_method])
    sns.boxplot(x='model_name', y=scoring_method, data=cv_df)
    sns.stripplot(x='model_name', y=scoring_method, data=cv_df, 
                  size=8, jitter=True, edgecolor="gray", linewidth=2)
    plt.title('Scoring Method={}'.format(scoring_method))
    plt.xticks(rotation=45)
    a=plt.show()
    print(cv_df.groupby('model_name')[scoring_method].mean())
    return cv_df


def evaluate_model_stats(model,X_train, X_test, y_train, y_test,train=True):
    if train:
        model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    y_pred_probs=model.predict_proba(X_test)
    conf_mat = confusion_matrix(y_test, y_pred)
    fig, ax = plt.subplots(figsize=(10,10))
   # sns.heatmap(conf_mat, annot=True, fmt='d',
                #xticklabels=AUTHOR_ID.keys(), yticklabels=AUTHOR_ID.keys())
    sns.heatmap(conf_mat, annot=True, fmt='d')
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.title("{} Confusion Martix".format(model.__class__.__name__))

    print(metrics.classification_report(y_test, y_pred, target_names=['No-Popular','Popular']))

    #calculate log-loss
    print("{}:Log-Loss:{}".format(model.__class__.__name__,log_loss(y_test,y_pred_probs)))
    return model,y_pred,y_pred_probs,conf_mat


#Using Accuracy
models = [
    #LinearSVC(),
    #MultinomialNB(),
    LogisticRegression(solver='sag',random_state=0),
]

#accuracy_cv_df=evaluate_models(features,labels,models,scoring_method='accuracy')


#Using Neg-Log-Loss
models_2 = [
    MultinomialNB(),
    LogisticRegression(solver='sag',random_state=0)
]

#log_loss_cv_df = evaluate_models(features,labels,models_2,scoring_method='neg_log_loss')

# %%
decade = 2000
data=all_songs[all_songs['decade']==decade]
data.loc[:,'genre_id']=data['genre'].map(lambda x: GENRES.index(x))
selected = selected_columns
selected.append('genre_id')
labels=data['popular'].values
filtered_data = data[selected_columns]

scaled_data=scale_features(filtered_data)

# %%
data.describe().plot(kind='box')

# %%
scaled_data.describe().plot(kind='box')

# %%
accuracy_cv_df=evaluate_models(scaled_data,labels,models,scoring_method='accuracy')
# Out:
# model_name
# LogisticRegression    0.727291
# Name: accuracy, dtype: float64

# %%
#split train/test the vectorized features
X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(scaled_data, labels, scaled_data.index, test_size=0.20, random_state=0)




#Logit model
model = LogisticRegression(solver='sag',random_state=0)
z=evaluate_model_stats(model,X_train, X_test, y_train, y_test)

# #NB Model
# model = MultinomialNB()
# z=evaluate_model_stats(model,X_train, X_test, y_train, y_test)
# Out:
#              precision    recall  f1-score   support
#
#  No-Popular       0.80      0.06      0.11        71
#     Popular       0.76      1.00      0.86       211
#
# avg / total       0.77      0.76      0.67       282
#
# LogisticRegression:Log-Loss:0.5369095805045476
